# %% [markdown]
# ## Lab 2

# %% [markdown]
# Welcome to the second lab of the AIML!
# In addition to implementing code, there will be questions that you must answer which relate to the lab and your implementation. Each question you will answer is preceded by a **'Question X'** header. Carefully read each question and provide you answer or code in the following textboxes with **'Answer:'** header. Your lab submission will be evaluated based on your answers to each of the questions and the implementation you provide.

# %% [markdown]
# # Every question is of 1 mark.

# %% [markdown]
# ## Overview

# %% [markdown]
# This module covers,
#
# 1) One sample and Two sample t-tests
#
# 2) ANOVA
#
# 3) Type I and Type II errors
#
# 4) Probabilty Distributions
#
# 5) Linear Regression

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# The purpose of the test is to tell if there is any significant difference between two data sets.

# %% [markdown]
# ## Question 1
#
# *A student is trying to decide between two GPUs. He want to use the GPU for his research to run Deep learning algorithms, so the only thing he is concerned with is speed.*
#
# *He picks a Deep Learning algorithm on a large data set and runs it on both GPUs 15 times, timing each run in hours. Results are given in the below lists GPU1 and GPU2.*

# %% [markdown]
# Hint: You can import ttest function from scipy to perform t tests

# %% [markdown]
# Given,
#
# Null Hypothesis : There is no significant difference between data sets
#
# Alternate Hypothesis : There is a significant difference
#
# *Do two-sample testing and check whether to reject Null Hypothesis or not.*
#
# #### Answer:

# %%
import pandas as pd
GPU1 = pd.DataFrame([11,9,10,11,10,12,9,11,12,9,11,12,9,10,9])
GPU2 = pd.DataFrame([11,13,10,13,12,9,11,12,12,11,12,12,10,11,13])

# %%
from scipy import stats
t_stat, pval = stats.ttest_ind(GPU1, GPU2)
if pval < 0.05:
    print ("Pval=",pval, "Reject Ho. I.e., There is a significant difference")
# Out:
# Pval= [0.01379428] Reject Ho. I.e., There is a significant difference

# %% [markdown]
# ## Question 2
# He is trying a third GPU which is GPU3.

# %%
GPU3 = pd.DataFrame([9,10,9,11,10,13,12,9,12,12,13,12,13,10,11])

#Assumption: Both the datasets (GPU1 & GPU 3) are random, independent, parametric & normally distributed

# %% [markdown]
# *Do two-sample testing and check whether there is significant differene between speeds of two GPUs GPU1 and GPU3.*
#
# #### Answer:

# %%
t_stat, pval = stats.ttest_ind(GPU1, GPU3)
if pval < 0.05:
    print ("Pval=",pval, "Reject Ho. I.e., There is a significant difference.")
else:
    print ("Pval=",pval, "Don't Reject Ho. I.e., There is *no* a significant difference.")
# Out:
# Pval= [0.14509211] Don't Reject Ho. I.e., There is *no* a significant difference.

# %% [markdown]
# ### ANOVA

# %% [markdown]
# ## Question 3
#
# If you need to compare more than two data sets at a time, an ANOVA is your best bet.
#
# *The results from three experiments with overlapping 95% confidence intervals are given below, and we want to confirm that the results for all three experiments are not significantly different.*
#
# #Assumption: All the 3 datasets (e1,e2 & e3) are random, independent, parametric & normally distributed
# But before conducting ANOVA, test equality of variances (using Levene's test) is satisfied or not. If not, then mention that we cannot depend on the result of ANOVA

# %%
import pandas as pd
e1 = pd.DataFrame([1.595440,1.419730,0.000000,0.000000])
e2 = pd.DataFrame([1.433800,2.079700,0.892139,2.384740])
e3 = pd.DataFrame([0.036930,0.938018,0.995956,1.006970])

# %% [markdown]
# Hint - You can use stats.levene function and stats.f_oneway function.

# %% [markdown]
# #### Answer:

# %%
#Levene:
#Ho - All variances are equal
#Ha - All variances are not equal
stat,pval = stats.levene(e1[0].values,e2[0].values, e3[0].values)
print("Pval=",pval)
if (pval<0.05):
    print("Reject Ho. Variance are not equal. ANOVA test is not dependable.")
else:
    print("Dont Reject Ho. Variance are equal. ANOVA test is dependable.")
# Out:
# Pval= 0.12259792666001798
# Dont Reject Ho. Variance are equal. ANOVA test is dependable.

# %%
f, p = stats.f_oneway(e1,e2,e3)
 
print ('One-way ANOVA')
print ('=============')
print ('F value:', f)
print ('P value:', p, '\n')

if(p<0.05):
    print("We can say that atleast one of the means is significantly different")
else:
    print("We can say all of the means are not significantly different")
# Out:
# One-way ANOVA
# ...
# F value: [2.51357623]
# P value: [0.13574645]
#
# We can say all of the means are not significantly different

# %% [markdown]
# ## Question 4
#
# *In one or two sentences explain about **TypeI** and **TypeII** errors.*
#
# #### Answer:

# %%
A type I error is the incorrect rejection of a true null hypothesis.

# %%
A type II error is the failure to reject a false null hypothesis.

# %% [markdown]
# # Question 5
# You are a manager of a chinese restaurant. You want to determine whether the waiting time to place an order has changed in the past month from its previous population mean value of 4.5 minutes.
# State the null and alternative hypothesis.

# %%
u0 = Waiting time of past month

# %%
Ho -> u0 = 4.5

# %%
Ha -> u0 != 4.5

# %% [markdown]
# # Question 6
# Get the binomial distribution with n = 10, p = .7 and k = [0, 1, 2, 3, 4, 5, 6, 7]
#
# Hint - Use stats.binom.pmf() function for this.

# %%
n = 10
p = .7
k = [0, 1, 2, 3, 4, 5, 6, 7]
b = stats.binom.pmf(k,n,p)
print(b)
# Out:
# [5.90490000e-06 1.37781000e-04 1.44670050e-03 9.00169200e-03
#  3.67569090e-02 1.02919345e-01 2.00120949e-01 2.66827932e-01]

# %% [markdown]
# # Question 7
# Plot the distribution created in the above question.

# %%
import matplotlib.pyplot as plt
plt.plot(k, b, "o-")

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Here we will try to see that if we can make a regression model to predict one column of a dataset by the use of other coloumn.
#
# ## Dataset
#
# Population of U.S. Cities
#
# ### Description
# The bigcity data frame has 49 rows and 2 columns.
#
# The measurements are the population (in 1000's) of 49 U.S. cities in 1920 and 1930. The 49 cities are a random sample taken from the 196 largest cities in 1920.
#
# ### Format
# This data frame contains the following columns:
#
# `u`
# The 1920 population.
#
# `x`
# The 1930 population.
#
# There is one unnamed column also in this dataset. Please remove and ignore that coloumn.
#
# Source
#
# The data were obtained from
#
# Cochran, W.G. (1977) Sampling Techniques. Third edition. John Wiley
#
# References
#
# Davison, A.C. and Hinkley, D.V. (1997) Bootstrap Methods and Their Application. Cambridge University Press.

# %% [markdown]
# # Question 8
# Read the dataset given in file named 'bigcity.csv'.

# %%
data = pd.read_csv("bigcity.csv")
data.head()
# Out:
#    Unnamed: 0    u    x
# 0           1  138  143
# 1           2   93  104
# 2           3   61   69
# 3           4  179  260
# 4           5   48   75

# %% [markdown]
# # Question 9 - Transform the dataset
# Find the number of rows in given dataset and separate the input(u column)  and target variables(x column) into X and Y.
#
# Remove the unnamed coloumn.
#
# Hint: You can shape function to get the size of the dataframe

# %%
data = data.drop(data.columns[0], axis=1)
data.head()
# Out:
#      u    x
# 0  138  143
# 1   93  104
# 2   61   69
# 3  179  260
# 4   48   75

# %%
print("Rows = ", data.shape[0])
X = data["u"].values
y = data["x"].values
print(X[:5], y[:5])
# Out:
# Rows =  49
# [138  93  61 179  48] [143 104  69 260  75]

# %% [markdown]
# ## Question 10 - Check the dataset for any missing values and also print out the correlation matrix

# %% [markdown]
# You can use .isna() and .corr() functions to check NA's and correlation in the dataframe respectively

# %%
data.isna().sum()
# Out:
# u    0
# x    0
# dtype: int64

# %%
data.corr()
# Out:
#           u         x
# u  1.000000  0.981742
# x  0.981742  1.000000

# %% [markdown]
# ### The high correlation betwwen u and x indicates that the variable u is a good predictor of variable x

# %% [markdown]
# # Question 11 - Split data into train, test sets
# Divide the data into training and test sets with 80-20 split using scikit-learn. Print the shapes of training and test feature sets.*

# %% [markdown]
# Check: train_test_split function

# %%
from sklearn.model_selection  import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print("X_train=", X_train.shape[0])
print("X_test=", X_test.shape[0])
print("y_train=", y_train.shape[0])
print("y_test=", y_test.shape[0])
# Out:
# X_train= 39
# X_test= 10
# y_train= 39
# y_test= 10

# %%
# Out:
# (39,)
# (39, 1)

# %% [markdown]
# # Question 12 - Find coefficients & intercept
# Estimate the coefficients b0 and b1 using scikit-learn.

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train.reshape(-1,1), y_train.reshape(-1,1))

# %%
print ("Coef =", reg.coef_)
print ("Intercept =",reg.intercept_)
# Out:
# Coef = [[1.1541281]]
# Intercept = [9.43607378]

# %% [markdown]
# Check: coef_ and intercept_ functions can help you get coefficients & intercept

# %% [markdown]
# # Question 13 - Linear Relationship between feature and target
# Plot the line with b1 and b0 as slope and y-intercept.
#
# Hint - y = mx + c, plot y

# %%
import numpy as np
plt.scatter(X_train, y_train)
plt.plot(X_train, reg.coef_[0]*X_train+reg.intercept_[0])

# %% [markdown]
# # Question 14 - Evaluation of model with scikit-learn
# Validate the model with Root Mean Squares error and R^2 score using scikit-learn. RMSE and R2 for test data and prediction

# %% [markdown]
# Hint: You can import mean_squared_error function & r2 (R square) from sklearn.metrics. Performing root operation over mean square error over mean square error gives you root mean square error

# %%
y_pred = reg.predict(X_test.reshape(-1,1))

from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE=", rmse)

r2score = r2_score(y_test, y_pred)
print("R2=", r2score)
# Out:
# RMSE= 8.19780139772148
# R2 0.9948774706743669

# %%
print(rmse)
# Out:
# 8.19780139772148

# %% [markdown]
# ## Question 15 - Calculate the accuracy of the model for both training and test data set

# %% [markdown]
# ### Hint: .score() function

# %%
print("Accuracy score for Training data:")
reg.score(reg.predict(X_train.reshape(-1,1)), y_train.reshape(-1,1))
# Out:
# Accuracy score for Training data:
# 0.877380447033662

# %%
print("Accuracy score for Test data:")
reg.score(reg.predict(X_test.reshape(-1,1)), y_test.reshape(-1,1))
# Out:
# Accuracy score for Test data:
# 0.9006003617476489
